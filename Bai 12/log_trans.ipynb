# %%
import numpy as np
from PIL import Image 
import math
import matplotlib.pyplot as plt

#im = img.imread("Pictures/coins.png")

im = Image.open("../Image/Fig0323(a)(mars_moon_phobos).tif")
im_arr = np.array(im)



c= 255/math.log(1+np.max(im_arr))
d= 5000
im_out = (c*np.log(1+ (np.exp(d)-1)*im_arr))

im_transformed = Image.fromarray(im_out)
# im_transformed.save("./cameraman_log_transform_.tif")
plt.imshow(im_transformed, cmap='gray')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20920\3939706734.py:15: RuntimeWarning: overflow encountered in exp
#   im_out = (c*np.log(1+ (np.exp(d)-1)*im_arr))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20920\3939706734.py:15: RuntimeWarning: invalid value encountered in multiply
#   im_out = (c*np.log(1+ (np.exp(d)-1)*im_arr))

# %%
plt.imshow(im_arr, cmap='gray')
